# %% [markdown]
# <a href="https://colab.research.google.com/github/vsnupoudel/DeepLearning-Exercises/blob/main/95_of_Testing_and_Training_of_Hair_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hair segmentation using DeepLearning

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# Download images and choose appropriate images

# %%
import pathlib
dataset_url = "http://projects.i-ctm.eu/sites/default/files/AltroMateriale/207_Michele%20Svanera/Figaro1k.zip"
data_dir = tf.keras.utils.get_file(origin=dataset_url
                                   ,extract=True
                                   , fname = 'Figaro1k_Photos')
file_dir = pathlib.Path(data_dir)
# Out:
# Downloading data from http://projects.i-ctm.eu/sites/default/files/AltroMateriale/207_Michele%20Svanera/Figaro1k.zip
# 66543616/66542098 [==============================] - 5s 0us/step

# %%
# !ls -all  /root/.keras/datasets/Figaro1k/GT/Training

# %% [markdown]
# Prepare a sorted list of images.

# %%
import datetime, os
base_dir = '/root/.keras/datasets/Figaro1k/'

# Directory with the training pictures
training_dir = os.path.join(base_dir, 'Original/Training')
testing_dir = os.path.join(base_dir, 'Original/Testing')

# Directory with our target pictures pictures
training_mask_dir = os.path.join(base_dir, 'GT/Training')
testing_mask_dir = os.path.join(base_dir, 'GT/Testing')

input_img_paths = sorted(
    [
        os.path.join(training_dir, fname)
        for fname in os.listdir(training_dir)
        if fname.endswith(".jpg")
    ] )
target_img_paths = sorted(
    [
        os.path.join(training_mask_dir, fname)
        for fname in os.listdir(training_mask_dir)
        if fname.endswith("gt.pbm") 
    ] )

test_img_paths = sorted([
        os.path.join(testing_dir, fname)
        for fname in os.listdir(testing_dir)
        if fname.endswith(".jpg")
    ] )

test_mask_paths = sorted([
        os.path.join(testing_mask_dir, fname)
        for fname in os.listdir(testing_mask_dir)
        if fname.endswith("gt.pbm")
    ] )

print("Number of samples:", len(input_img_paths))

for input_path, target_path in zip(input_img_paths[:5], target_img_paths[:5]):
    print(input_path, "|", target_path)
# Out:
# Number of samples: 840
# /root/.keras/datasets/Figaro1k/Original/Training/Frame00001-org.jpg | /root/.keras/datasets/Figaro1k/GT/Training/Frame00001-gt.pbm
# /root/.keras/datasets/Figaro1k/Original/Training/Frame00002-org.jpg | /root/.keras/datasets/Figaro1k/GT/Training/Frame00002-gt.pbm
# /root/.keras/datasets/Figaro1k/Original/Training/Frame00003-org.jpg | /root/.keras/datasets/Figaro1k/GT/Training/Frame00003-gt.pbm
# /root/.keras/datasets/Figaro1k/Original/Training/Frame00004-org.jpg | /root/.keras/datasets/Figaro1k/GT/Training/Frame00004-gt.pbm
# /root/.keras/datasets/Figaro1k/Original/Training/Frame00005-org.jpg | /root/.keras/datasets/Figaro1k/GT/Training/Frame00005-gt.pbm

# %% [markdown]
# Plot the images and their masks, 9 at a time...

# %%
pic_index = 100

# %%
import matplotlib.image as mpimg

pic_index+=9
# Display input image #7
fig, ax = plt.subplots(3,3 , figsize=(9,9))
fig1, ax1 = plt.subplots(3,3 , figsize=(9,9))
for i in range(3):
  for j in range(3):    
    img = mpimg.imread( input_img_paths[pic_index]  )
    ax[i,j].imshow( img )
    img = mpimg.imread( target_img_paths[pic_index]  )
    ax1[i,j].imshow( img )
    pic_index+= 1
# display(Image(filename=input_img_paths[9]))
plt.show()

# %% [markdown]
# Putting the images in a batch like format.
# Reference. [link text](https://keras.io/examples/vision/oxford_pets_image_segmentation/)

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import array_to_img

img_size = (256, 256)
num_classes = 2
batch_size = 32

class HairSegSeq(keras.utils.Sequence):
    """Helper to iterate over the data (as Numpy arrays)."""

    def __init__(self, batch_size, img_size, input_img_paths, target_img_paths):
        self.batch_size = batch_size
        self.img_size = img_size
        self.input_img_paths = input_img_paths
        self.target_img_paths = target_img_paths

    def __len__(self):
        return len(self.input_img_paths) // self.batch_size

    def __getitem__(self, idx):
        """Returns tuple (input, target) correspond to batch #idx."""
        i = idx * self.batch_size
        batch_input_img_paths = self.input_img_paths[i : i + self.batch_size]
        batch_target_img_paths = self.target_img_paths[i : i + self.batch_size]
        x = np.zeros((self.batch_size,) + self.img_size + (3,), dtype="float32")

        for j, path in enumerate(batch_input_img_paths):
            img = load_img(path, target_size=self.img_size)
            #  tf.cast(input_image, tf.float32) / 255.0
            arr = tf.cast( img_to_array(img)/255.0 , tf.float32) 
            # img = array_to_img( arr, scale = False )
            x[j] = arr
        y = np.zeros((self.batch_size,) + self.img_size + (1,), dtype="uint8")
        for j, path in enumerate(batch_target_img_paths):
            img = load_img(path, target_size=self.img_size, color_mode="grayscale")
            y[j] = np.expand_dims(img, 2)
            y[j] = np.where( y[j] ==255,1 , 0 )
            # y[j] -= 1
        return x, y

# %% [markdown]
# Test the batch-like format.

# %%
train_gen = HairSegSeq(
    batch_size, img_size, test_img_paths, test_mask_paths
)

# %%
train_gen.__getitem__(0)[0].shape
# Out:
# (32, 256, 256, 3)

# %% [markdown]
# Prepare U-Net Xception-style model

# %%
from tensorflow.keras import layers

def get_model(img_size, num_classes):
    inputs = keras.Input(shape=img_size + (3,))

    ### [First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(32, 3, strides=2, padding="same")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    # Blocks 1, 2, 3 are identical apart from the feature depth.
    for filters in [64, 128, 256]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(filters, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    ### [Second half of the network: upsampling inputs] ###

    for filters in [256, 128, 64, 32]:
        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.UpSampling2D(2)(x)

        # Project residual
        residual = layers.UpSampling2D(2)(previous_block_activation)
        residual = layers.Conv2D(filters, 1, padding="same")(residual)
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    # Add a per-pixel classification layer
    outputs = layers.Conv2D(1, 3 , activation="sigmoid", padding="same")(x)

    # Define the model
    model = keras.Model(inputs, outputs)
    return model

# Free up RAM in case the model definition cells were run multiple times
keras.backend.clear_session()

# Build model
model = get_model(img_size, num_classes)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128, 128, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 32) 0           activation[0][0]
# __________________________________________________________________________________________________
# separable_conv2d (SeparableConv (None, 128, 128, 64) 2400        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 64) 256         separable_conv2d[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 128, 128, 64) 4736        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 64) 256         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 64)   2112        activation[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64, 64, 64)   0           max_pooling2d[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 64, 64, 128)  8896        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 128)  512         separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 64, 64, 128)  17664       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 128)  512         separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 128)  8320        add[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 128)  0           max_pooling2d_1[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 32, 32, 256)  34176       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 256)  1024        separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 32, 32, 256)  68096       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 256)  1024        separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 256)  33024       add_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 256)  0           max_pooling2d_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 256)  590080      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 256)  1024        conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 256)  590080      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 256)  1024        conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 256)  65792       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 256)  0           up_sampling2d[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 128)  295040      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 128)  512         conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 32, 32, 128)  147584      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 128)  512         conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 128)  32896       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 64, 64, 128)  0           up_sampling2d_2[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 64, 64, 128)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 64, 64, 64)   73792       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 64, 64, 64)   256         conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 64, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 64, 64, 64)   36928       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 64)   256         conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 128, 128, 128 0           add_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 64) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 128, 64) 8256        up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 128, 128, 64) 0           up_sampling2d_4[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 128, 128, 64) 0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 128, 128, 32) 18464       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 128, 128, 32) 128         conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 128, 128, 32) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 128, 128, 32) 9248        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 128, 128, 32) 128         conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 256, 256, 64) 0           add_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 256, 256, 32) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 256, 256, 32) 2080        up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 256, 256, 32) 0           up_sampling2d_6[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 256, 256, 1)  289         add_6[0][0]
# ==================================================================================================
# Total params: 2,058,401
# Trainable params: 2,054,625
# Non-trainable params: 3,776
# __________________________________________________________________________________________________

# %% [markdown]
# Set aside validation samples.

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png')

# %%
train_gen = HairSegSeq(
    batch_size, img_size, input_img_paths, target_img_paths
)
val_gen = HairSegSeq(batch_size, img_size, test_img_paths , test_mask_paths )

# %% [markdown]
# Train the model.

# %%
# Experimenting with the learning rate
model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate = 0.0005 )
              , loss="binary_crossentropy", metrics = ['accuracy'])

checkpoint_filepath = '/content'
callbacks = [ keras.callbacks.ModelCheckpoint(  filepath= checkpoint_filepath+"/hair_segmentation.h5"
                                    ,save_best_only=True)]

logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# %%
# Train the model, doing validation at the end of each epoch.
epochs = 60
model.fit(train_gen, epochs=epochs, validation_data=val_gen
          , callbacks= [callbacks , tensorboard_callback ] )
# Out:
# Epoch 1/100
# 26/26 [==============================] - 64s 1s/step - loss: 1.4846 - accuracy: 0.7731 - val_loss: 6.3287 - val_accuracy: 0.6510
# Epoch 2/100
# 26/26 [==============================] - 26s 982ms/step - loss: 0.3082 - accuracy: 0.8755 - val_loss: 4.0586 - val_accuracy: 0.6508
# Epoch 3/100
# 26/26 [==============================] - 26s 985ms/step - loss: 0.3219 - accuracy: 0.8759 - val_loss: 2.4953 - val_accuracy: 0.6506
# Epoch 4/100
# 26/26 [==============================] - 26s 985ms/step - loss: 0.2208 - accuracy: 0.9102 - val_loss: 2.2050 - val_accuracy: 0.6508
# Epoch 5/100
# 26/26 [==============================] - 26s 989ms/step - loss: 0.2855 - accuracy: 0.8866 - val_loss: 0.9905 - val_accuracy: 0.6391
# Epoch 6/100
# 26/26 [==============================] - 26s 986ms/step - loss: 0.2088 - accuracy: 0.9132 - val_loss: 0.7411 - val_accuracy: 0.6234
# Epoch 7/100
# 26/26 [==============================] - 26s 994ms/step - loss: 0.2268 - accuracy: 0.9051 - val_loss: 0.5845 - val_accuracy: 0.6109
# Epoch 8/100
# 26/26 [==============================] - 26s 989ms/step - loss: 0.1902 - accuracy: 0.9220 - val_loss: 0.6107 - val_accuracy: 0.6277
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 9/100
# 26/26 [==============================] - 26s 985ms/step - loss: 0.1862 - accuracy: 0.9235 - val_loss: 0.5541 - val_accuracy: 0.6693
# Epoch 10/100
# 26/26 [==============================] - 26s 988ms/step - loss: 0.1803 - accuracy: 0.9249 - val_loss: 0.5660 - val_accuracy: 0.7044
# Epoch 11/100
# 26/26 [==============================] - 26s 995ms/step - loss: 0.1604 - accuracy: 0.9342 - val_loss: 0.6074 - val_accuracy: 0.6329
# Epoch 12/100
# 26/26 [==============================] - 26s 988ms/step - loss: 0.1701 - accuracy: 0.9308 - val_loss: 0.5545 - val_accuracy: 0.6883
# Epoch 13/100
# 26/26 [==============================] - 26s 991ms/step - loss: 0.1778 - accuracy: 0.9267 - val_loss: 0.5953 - val_accuracy: 0.6521
# Epoch 14/100
# 26/26 [==============================] - 26s 990ms/step - loss: 0.1696 - accuracy: 0.9305 - val_loss: 0.5693 - val_accuracy: 0.6776
# Epoch 15/100
# 26/26 [==============================] - 26s 993ms/step - loss: 0.1540 - accuracy: 0.9369 - val_loss: 0.6279 - val_accuracy: 0.6534
# Epoch 16/100
# 26/26 [==============================] - 26s 988ms/step - loss: 0.1571 - accuracy: 0.9357 - val_loss: 0.5516 - val_accuracy: 0.7149
# Epoch 17/100
# 26/26 [==============================] - 26s 991ms/step - loss: 0.1491 - accuracy: 0.9392 - val_loss: 0.6743 - val_accuracy: 0.6732
# Epoch 18/100
# 26/26 [==============================] - 26s 989ms/step - loss: 0.1424 - accuracy: 0.9429 - val_loss: 0.7364 - val_accuracy: 0.6817
# Epoch 19/100
# 26/26 [==============================] - 26s 990ms/step - loss: 0.1323 - accuracy: 0.9468 - val_loss: 0.6620 - val_accuracy: 0.7268
# Epoch 20/100
# 26/26 [==============================] - 26s 994ms/step - loss: 0.1351 - accuracy: 0.9459 - val_loss: 0.8526 - val_accuracy: 0.7006
# Epoch 21/100
# 26/26 [==============================] - 26s 993ms/step - loss: 0.1411 - accuracy: 0.9426 - val_loss: 0.8724 - val_accuracy: 0.7171
# Epoch 22/100
# 26/26 [==============================] - 26s 996ms/step - loss: 0.1296 - accuracy: 0.9478 - val_loss: 0.8139 - val_accuracy: 0.7299
# Epoch 23/100
# 26/26 [==============================] - 26s 992ms/step - loss: 0.1233 - accuracy: 0.9506 - val_loss: 0.6850 - val_accuracy: 0.7631
# Epoch 24/100
# 26/26 [==============================] - 26s 991ms/step - loss: 0.1195 - accuracy: 0.9526 - val_loss: 0.5508 - val_accuracy: 0.8011
# Epoch 25/100
# 26/26 [==============================] - 26s 988ms/step - loss: 0.1204 - accuracy: 0.9517 - val_loss: 0.5209 - val_accuracy: 0.8161
# Epoch 26/100
# 26/26 [==============================] - 26s 998ms/step - loss: 0.1228 - accuracy: 0.9509 - val_loss: 0.4741 - val_accuracy: 0.8481
# Epoch 27/100
# 26/26 [==============================] - 26s 985ms/step - loss: 0.1137 - accuracy: 0.9552 - val_loss: 0.3348 - val_accuracy: 0.8799
# Epoch 28/100
# 26/26 [==============================] - 26s 987ms/step - loss: 0.1110 - accuracy: 0.9559 - val_loss: 0.2828 - val_accuracy: 0.8955
# Epoch 29/100
# 26/26 [==============================] - 26s 992ms/step - loss: 0.1188 - accuracy: 0.9530 - val_loss: 0.2049 - val_accuracy: 0.9182
# Epoch 30/100
# 26/26 [==============================] - 26s 990ms/step - loss: 0.1011 - accuracy: 0.9600 - val_loss: 0.2469 - val_accuracy: 0.9108
# Epoch 31/100
# 26/26 [==============================] - 26s 997ms/step - loss: 0.0991 - accuracy: 0.9608 - val_loss: 0.2111 - val_accuracy: 0.9203
# Epoch 32/100
# 26/26 [==============================] - 26s 993ms/step - loss: 0.1025 - accuracy: 0.9593 - val_loss: 0.1968 - val_accuracy: 0.9220
# Epoch 33/100
# 26/26 [==============================] - 26s 988ms/step - loss: 0.0947 - accuracy: 0.9625 - val_loss: 0.1971 - val_accuracy: 0.9250
# Epoch 34/100
# 26/26 [==============================] - 26s 996ms/step - loss: 0.0847 - accuracy: 0.9664 - val_loss: 0.2089 - val_accuracy: 0.9230
# Epoch 35/100
# 26/26 [==============================] - 26s 993ms/step - loss: 0.0867 - accuracy: 0.9657 - val_loss: 0.2064 - val_accuracy: 0.9235
# Epoch 36/100
# 26/26 [==============================] - 26s 994ms/step - loss: 0.0886 - accuracy: 0.9648 - val_loss: 0.1965 - val_accuracy: 0.9258
# Epoch 37/100
# 26/26 [==============================] - 26s 990ms/step - loss: 0.0922 - accuracy: 0.9636 - val_loss: 0.2888 - val_accuracy: 0.9074
# Epoch 38/100
# 26/26 [==============================] - 26s 996ms/step - loss: 0.0933 - accuracy: 0.9628 - val_loss: 0.2217 - val_accuracy: 0.9218
# Epoch 39/100
# 26/26 [==============================] - 26s 999ms/step - loss: 0.0803 - accuracy: 0.9681 - val_loss: 0.2007 - val_accuracy: 0.9260
# Epoch 40/100
# 26/26 [==============================] - 26s 1s/step - loss: 0.0768 - accuracy: 0.9693 - val_loss: 0.2040 - val_accuracy: 0.9263
# Epoch 41/100
# 26/26 [==============================] - 26s 995ms/step - loss: 0.0811 - accuracy: 0.9676 - val_loss: 0.2071 - val_accuracy: 0.9265
# Epoch 42/100
# 26/26 [==============================] - 26s 993ms/step - loss: 0.0743 - accuracy: 0.9703 - val_loss: 0.2227 - val_accuracy: 0.9238
# Epoch 43/100
# 26/26 [==============================] - 26s 989ms/step - loss: 0.0705 - accuracy: 0.9718 - val_loss: 0.2161 - val_accuracy: 0.9257
# Epoch 44/100
# 26/26 [==============================] - 26s 997ms/step - loss: 0.0619 - accuracy: 0.9752 - val_loss: 0.2192 - val_accuracy: 0.9232
# Epoch 45/100
# 26/26 [==============================] - 26s 992ms/step - loss: 0.0667 - accuracy: 0.9733 - val_loss: 0.2257 - val_accuracy: 0.9257
# Epoch 46/100
# 26/26 [==============================] - 26s 991ms/step - loss: 0.0618 - accuracy: 0.9753 - val_loss: 0.2193 - val_accuracy: 0.9242
# Epoch 47/100
# 26/26 [==============================] - 26s 987ms/step - loss: 0.0609 - accuracy: 0.9755 - val_loss: 0.2244 - val_accuracy: 0.9269
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 5e-05.
# Epoch 48/100
# 26/26 [==============================] - 26s 996ms/step - loss: 0.0651 - accuracy: 0.9739 - val_loss: 0.2359 - val_accuracy: 0.9263
# Epoch 49/100
# 26/26 [==============================] - 26s 998ms/step - loss: 0.0633 - accuracy: 0.9745 - val_loss: 0.2253 - val_accuracy: 0.9265
# Epoch 50/100
# 26/26 [==============================] - 26s 995ms/step - loss: 0.0598 - accuracy: 0.9759 - val_loss: 0.2332 - val_accuracy: 0.9273
# Epoch 51/100
# 26/26 [==============================] - 26s 992ms/step - loss: 0.0575 - accuracy: 0.9768 - val_loss: 0.2329 - val_accuracy: 0.9266
# Epoch 52/100
# 26/26 [==============================] - 26s 992ms/step - loss: 0.0605 - accuracy: 0.9757 - val_loss: 0.2419 - val_accuracy: 0.9279
# Epoch 53/100
# 26/26 [==============================] - 26s 989ms/step - loss: 0.0610 - accuracy: 0.9753 - val_loss: 0.2380 - val_accuracy: 0.9276
# Epoch 54/100
# 26/26 [==============================] - 26s 993ms/step - loss: 0.0526 - accuracy: 0.9789 - val_loss: 0.2365 - val_accuracy: 0.9270
# Epoch 55/100
# 26/26 [==============================] - 26s 993ms/step - loss: 0.0559 - accuracy: 0.9775 - val_loss: 0.2416 - val_accuracy: 0.9268
# Epoch 56/100
# 26/26 [==============================] - 26s 996ms/step - loss: 0.0605 - accuracy: 0.9755 - val_loss: 0.2443 - val_accuracy: 0.9269
# Epoch 57/100
# 26/26 [==============================] - 26s 995ms/step - loss: 0.0491 - accuracy: 0.9803 - val_loss: 0.2460 - val_accuracy: 0.9278
# Epoch 58/100
# 26/26 [==============================] - 26s 994ms/step - loss: 0.0503 - accuracy: 0.9796 - val_loss: 0.2472 - val_accuracy: 0.9274
# Epoch 59/100
# 26/26 [==============================] - 26s 993ms/step - loss: 0.0545 - accuracy: 0.9780 - val_loss: 0.2482 - val_accuracy: 0.9273
# Epoch 60/100
# 26/26 [==============================] - 26s 993ms/step - loss: 0.0479 - accuracy: 0.9807 - val_loss: 0.2488 - val_accuracy: 0.9258
# Epoch 61/100
# 26/26 [==============================] - 26s 993ms/step - loss: 0.0502 - accuracy: 0.9797 - val_loss: 0.2532 - val_accuracy: 0.9258
# Epoch 62/100
# 26/26 [==============================] - 26s 1s/step - loss: 0.0523 - accuracy: 0.9789 - val_loss: 0.2553 - val_accuracy: 0.9264
# Epoch 63/100
# 26/26 [==============================] - 26s 990ms/step - loss: 0.0541 - accuracy: 0.9780 - val_loss: 0.2621 - val_accuracy: 0.9267
# Epoch 64/100
# 26/26 [==============================] - 26s 992ms/step - loss: 0.0617 - accuracy: 0.9747 - val_loss: 0.2618 - val_accuracy: 0.9262
# Epoch 65/100
# 26/26 [==============================] - 26s 991ms/step - loss: 0.0499 - accuracy: 0.9798 - val_loss: 0.2611 - val_accuracy: 0.9274
# Epoch 66/100
# 26/26 [==============================] - 26s 994ms/step - loss: 0.0483 - accuracy: 0.9804 - val_loss: 0.2609 - val_accuracy: 0.9254
# Epoch 67/100
# 26/26 [==============================] - 26s 987ms/step - loss: 0.0499 - accuracy: 0.9796 - val_loss: 0.2668 - val_accuracy: 0.9254
# Epoch 68/100
# 26/26 [==============================] - 26s 992ms/step - loss: 0.0479 - accuracy: 0.9807 - val_loss: 0.2698 - val_accuracy: 0.9251
# Epoch 69/100
# 26/26 [==============================] - 26s 995ms/step - loss: 0.0475 - accuracy: 0.9807 - val_loss: 0.2729 - val_accuracy: 0.9273
# Epoch 70/100
# 26/26 [==============================] - 26s 998ms/step - loss: 0.0468 - accuracy: 0.9810 - val_loss: 0.2821 - val_accuracy: 0.9243
# Epoch 71/100
# 26/26 [==============================] - 26s 989ms/step - loss: 0.0479 - accuracy: 0.9803 - val_loss: 0.2850 - val_accuracy: 0.9252
# Epoch 72/100
# 26/26 [==============================] - 26s 994ms/step - loss: 0.0471 - accuracy: 0.9807 - val_loss: 0.2845 - val_accuracy: 0.9238
# Epoch 73/100
# 26/26 [==============================] - 26s 989ms/step - loss: 0.0557 - accuracy: 0.9771 - val_loss: 0.2825 - val_accuracy: 0.9230
# Epoch 74/100
# 26/26 [==============================] - 26s 996ms/step - loss: 0.0590 - accuracy: 0.9757 - val_loss: 0.3028 - val_accuracy: 0.9195
# Epoch 75/100
# 26/26 [==============================] - 26s 996ms/step - loss: 0.0593 - accuracy: 0.9754 - val_loss: 0.2696 - val_accuracy: 0.9257
# Epoch 76/100
# 26/26 [==============================] - 26s 991ms/step - loss: 0.0495 - accuracy: 0.9795 - val_loss: 0.2725 - val_accuracy: 0.9248
# Epoch 77/100
# 26/26 [==============================] - 26s 994ms/step - loss: 0.0449 - accuracy: 0.9817 - val_loss: 0.2737 - val_accuracy: 0.9275
# Epoch 78/100
# 26/26 [==============================] - 26s 993ms/step - loss: 0.0445 - accuracy: 0.9818 - val_loss: 0.2692 - val_accuracy: 0.9266
# Epoch 79/100
# 26/26 [==============================] - 26s 993ms/step - loss: 0.0454 - accuracy: 0.9813 - val_loss: 0.2710 - val_accuracy: 0.9264
# Epoch 80/100
# 26/26 [==============================] - 26s 996ms/step - loss: 0.0514 - accuracy: 0.9787 - val_loss: 0.2728 - val_accuracy: 0.9258
# Epoch 81/100
# 26/26 [==============================] - 26s 993ms/step - loss: 0.0443 - accuracy: 0.9819 - val_loss: 0.2811 - val_accuracy: 0.9240
# Epoch 82/100
# 26/26 [==============================] - 26s 993ms/step - loss: 0.0393 - accuracy: 0.9839 - val_loss: 0.2810 - val_accuracy: 0.9269
# Epoch 83/100
# 26/26 [==============================] - 26s 989ms/step - loss: 0.0459 - accuracy: 0.9809 - val_loss: 0.3026 - val_accuracy: 0.9193
# Epoch 84/100
# 26/26 [==============================] - 26s 991ms/step - loss: 0.0467 - accuracy: 0.9807 - val_loss: 0.2862 - val_accuracy: 0.9254
# Epoch 85/100
# 26/26 [==============================] - 26s 988ms/step - loss: 0.0410 - accuracy: 0.9832 - val_loss: 0.2836 - val_accuracy: 0.9262
# Epoch 86/100
# 26/26 [==============================] - 26s 997ms/step - loss: 0.0438 - accuracy: 0.9818 - val_loss: 0.2891 - val_accuracy: 0.9265
# Epoch 87/100
# 26/26 [==============================] - 26s 990ms/step - loss: 0.0406 - accuracy: 0.9833 - val_loss: 0.2953 - val_accuracy: 0.9253
# Epoch 88/100
# 26/26 [==============================] - 26s 992ms/step - loss: 0.0417 - accuracy: 0.9828 - val_loss: 0.2827 - val_accuracy: 0.9261
# Epoch 89/100
# 26/26 [==============================] - 26s 987ms/step - loss: 0.0409 - accuracy: 0.9831 - val_loss: 0.3100 - val_accuracy: 0.9229
# Epoch 90/100
# 26/26 [==============================] - 26s 993ms/step - loss: 0.0530 - accuracy: 0.9784 - val_loss: 0.3511 - val_accuracy: 0.9176
# Epoch 91/100
# 26/26 [==============================] - 26s 993ms/step - loss: 0.0684 - accuracy: 0.9725 - val_loss: 0.3130 - val_accuracy: 0.9204
# Epoch 92/100
# 26/26 [==============================] - 26s 994ms/step - loss: 0.0510 - accuracy: 0.9790 - val_loss: 0.2831 - val_accuracy: 0.9275
# Epoch 93/100
# 26/26 [==============================] - 26s 989ms/step - loss: 0.0441 - accuracy: 0.9817 - val_loss: 0.2757 - val_accuracy: 0.9268
# Epoch 94/100
# 26/26 [==============================] - 26s 995ms/step - loss: 0.0453 - accuracy: 0.9812 - val_loss: 0.2769 - val_accuracy: 0.9269
# Epoch 95/100
# 26/26 [==============================] - 26s 986ms/step - loss: 0.0424 - accuracy: 0.9825 - val_loss: 0.2832 - val_accuracy: 0.9265
# Epoch 96/100
# 26/26 [==============================] - 26s 991ms/step - loss: 0.0436 - accuracy: 0.9818 - val_loss: 0.2888 - val_accuracy: 0.9262
# Epoch 97/100
# 26/26 [==============================] - 26s 986ms/step - loss: 0.0364 - accuracy: 0.9851 - val_loss: 0.2904 - val_accuracy: 0.9255
# Epoch 98/100
# 26/26 [==============================] - 26s 994ms/step - loss: 0.0383 - accuracy: 0.9842 - val_loss: 0.2957 - val_accuracy: 0.9268
# Epoch 99/100
# 26/26 [==============================] - 26s 993ms/step - loss: 0.0363 - accuracy: 0.9851 - val_loss: 0.3021 - val_accuracy: 0.9267
# Epoch 100/100
# 26/26 [==============================] - 26s 998ms/step - loss: 0.0419 - accuracy: 0.9825 - val_loss: 0.2982 - val_accuracy: 0.9259

# %% [markdown]
# Start Tensorboard to see the Loss and accuracy curves

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
# %tensorboard --logdir logs

# %% [markdown]
# Test to predict a fresh image, Upload here! This needs to be changed to capturing image via webcam later

# %%
from google.colab import files

uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
for fn in uploaded.keys():
  name = fn
img = mpimg.imread( name )
plt.imshow(img)

# %% [markdown]
# Predicting

# %% [markdown]
# Download the model

# %%
from google.colab import files
files.download( checkpoint_filepath+'/hair_segmentation.h5' )

# %% [markdown]
# Predict using the best model.

# %%
from keras.models import load_model
# returns a compiled model
# identical to the previous one
model_up = load_model(checkpoint_filepath+'/hair_segmentation.h5')

# %%
path = '/content/young-asian-woman-beautiful-long-260nw-1675898824.jpg'
img = load_img(path, target_size= (256,256))
arr = tf.cast( img_to_array(img)/255.0 , tf.float32) 
arr = np.expand_dims(arr, 0)
print( arr.shape)
output = model_up.predict( arr )

# %%
mask = np.squeeze(output, axis = (0,3) )
plt.imshow(mask, cmap='gray')
